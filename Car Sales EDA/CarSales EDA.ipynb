# %% [markdown]
# <img src = 'https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true' width="240" height="360">
#
# # Exploratory Data Analysis - Car Sales Data
#
# <img src="banner.jpeg" width='100%'><br/>

# %% [markdown]
# # Introduction
#
# Understand the data and derive simple models with Pandas as baseline. This is a critical and first step in analyzing the data and we do this for below reasons :
# - Finding patterns in Data
# - Determining relationships in Data
# - Checking of assumptions
# - Preliminary selection of appropriate models
# - Detection of mistakes
#
# __Exploratory Data Analysis (EDA) Essentials__
# 1. Problem Statement
# 2. Importing Packages
# 3. Shortlisting Data and Columns
# 4. Purification of Data
# 5. Analysis (Finding patterns in Data)
# 	+ Univariate
# 	+ Bivariate
# 	+ Multivariate
# 6. Uncover insights (Answer questions in the data)
# 7. Conclude (Story Telling)
# 8. Actionable Insights

# %% [markdown]
# ## Table of Contents
#
# 1. [Problem Statement](#section1)
# 2. [Importing Packages](#section2)
# 3. [Sortlisting Data & Columns](#section3)
#     - 3.1 [Loading Data](#section301)
#     - 3.2 [Understanding the Dataset](#section302)
#     - 3.3 [Description of the Dataset](#section303)
#     - 3.4 [Pre Profiling](#section304)
#     - 3.5 [Initial observations](#section305)
#     - 3.6 [Final observations](#section306)
#
# 4. [Data Normalization or Purification](#section4)
#     - 4.1 [Removal of Duplicates](#section401)
#     - 4.2 [Standardize all column headers to lower case](#section402)
#     - 4.3 [Handling categorical data & its imputation](#section403)
#     - 4.4 [Handling numerical data & imputation](#section404)
#
# 5. [Analysis & Identify patterns in the data](#section5)
#     - 5.1 [Univariate Analysis](#section501)
#         - 5.1.1 [Which brand of cars sold the most of the car?](#section50101)
#         - 5.1.2 [Which price range of cars sold the most of the car?](#section50102)
#         - 5.1.3 [Which body type of cars sold the most of the car?](#section50103)
#         - 5.1.4 [What is variation of the car sold in terms of mileage of the car?](#section50104)
#         - 5.1.5 [Which engine volume cars sold the most of the car?](#section50105)
#         - 5.1.6 [Which engine type cars sold the most of the car?](#section50106)
#         - 5.1.7 [What is effect of the car sold in terms of registration of the car?](#section50107)
#         - 5.1.8 [In which production year of cars sold the most of the car?](#section50108)
#         - 5.1.9 [Which model type of cars sold the most of the car of the car?](#section50109)
#         - 5.1.10 [Which drive type of cars sold the most of the car?](#section501010)
#
#     - 5.2 [Bivariate Analysis](#section502)
#         - 5.2.1 [Which model is the most prefered in top brands of the car?](#section50201)
#         - 5.2.2 [Which drive type is the most prefered in top brands of the car?](#section50202)
#         - 5.2.3 [Which fuel type is the most prefered in top brands of the car?](#section50203)
#         - 5.2.4 [Average price of vehicle by brands?](#section50204)
#         - 5.2.5 [Average price of vehicle by body type?](#section50205)
#         - 5.2.6 [Average price of vehicle by drive type?](#section50206)
#         - 5.2.7 [Average price of vehicle by mileage?](#section50207)
#         - 5.2.8 [Average price of vehicle by fuel type?](#section50208)
#         - 5.2.9 [Most preferred registration mode over the years of the car?](#section50209)
#         - 5.2.10 [Most prefered drive type with mileage of the car?](#section50210)
#         - 5.2.11 [Most prefered drive type with body type of the car?](#section50211)
#         - 5.2.12 [Most prefered engine volume with mileage of the car?](#section50211)
#
#     - 5.3 [Multivariate Analysis](#section503)
#         - 5.3.1 [Pair Plot - What all variables paired with all the other variables of the car?](#section50301)
#         - 5.3.2 [Average price of vehicle by body type and drive type of the car?](#section50302)
#         - 5.3.3 [Average price of vehicle by engine type and drive type of the car?](#section50303)
#         - 5.3.4 [Average price of vehicle by mileage and registration of the car?](#section50304)
#         - 5.3.5 [Average price of vehicle by vehicles by fuel type and drive?](#section50305)
#         - 5.3.6 [Average price of vehicle by mileage and drive of the car?](#section50306)
#         - 5.3.7 [Average price of vehicle by mileage and fuel type of the car?](#section50307)
#         - 5.3.8 [Average price of vehicles by mileage and eng type?](#section50308)
#         - 5.3.9 [Average price of vehicle by drive type over the years of the car (1950 - 2010)?](#section50309)
#         - 5.3.10 [Average price of vehicle by drive type over the years of the car (2010 - 2016)?](#section50310)
#         - 5.3.11 [Most preferred body type used over the years of the car?](#section50311)
#         - 5.3.12 [Most preferred eng type used over the years of the car?](#section50312)
#         - 5.3.13 [Most prefered sold or registered vehicle over the years?](#section50313)
#
# 6. [Uncover insights (Answer questions in the data)](#section6)
# 7. [Conclusions](#section7)
# 7. [Actionable Insights](#section8)

# %% [markdown]
# <a id=section1></a>
# ## 1. Problem Statement
#
# - __Which brand of the cars sold most?__
# - __What all the factors are affecting to the car buyers?__
# - __What all features most likely for high profile buyers?__
#
# Got this data from INSAID to prepare __Exploratory Data Analysis (EDA)__ with basic use of Pandas which includes __cleaning, munging, combining, reshaping, slicing, dicing__ and __transforming data__ for analysis purpose.
#
#
# The notebook has observations with each step in order to explain thoroughly how to approach the data set. Based on the observation some questions also are answered in the notebook for the reference though not all of them are explored in the analysis.

# %% [markdown]
# <a id=section2></a>
# ## 2. Importing Packages

# %%
import numpy as np                                  # Implemennts milti-dimensional array and matrices
import pandas as pd                                 # For data manipulation and analysis
pd.set_option('mode.chained_assignment', None)      # To suppress pandas warnings.
pd.set_option('display.max_colwidth', -1)           # To display all the data in each column
pd.options.display.max_columns = 50                 # To display every column of the dataset in head()

import pandas_profiling

# Plotting library for Python programming language and it's numerical mathematics extension NumPy
import matplotlib.pyplot as plt
# %matplotlib inline

params = {'legend.fontsize': 'large',
          'figure.figsize': (18.5, 10.5),
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large'}
plt.rcParams.update(params)

# Provides a high level interface for drawing attractive and informative statistical graphics
import seaborn as sns
sns.set(style='whitegrid', font_scale=1.3, color_codes=True)      # To apply seaborn styles to the plots.

# Ignore warning related to pandas_profiling
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id=section3></a>
# ## 3. Sortlisting Data & Columns
#
# - In the upcoming sections we will first __understand our dataset__ using various pandas functionalities.
# - Then with the help of __pandas profiling__ we will find which columns of our dataset need preprocessing.
# - In __preprocessing__ we will deal with erronous and missing values of columns.
# - Again we will do __pandas profiling__ to see how preprocessing have transformed our dataset.

# %% [markdown]
# <a id=section301></a>
# ### 3.1 Loading Data
#
# In this **Data Visualization** sheet we are using dataset about **Car Sale's**. This dataset contains information about the **Car Sales** with different **Manufacturer Brands and Models**.

# %%
# Importing training dataset using pd.read_csv
carsales_data = pd.read_csv("car_sales.csv",sep=',',encoding='latin-1')

# %% [markdown]
# While loading data we are getting UnicodeDecodeError - 'utf8' codec can't decode, invalid continuation byte error, as there are multiple rows having charecters like 'ïàññ' which all are in latin letters & by default UTF-8 charecter encoding is supported by Pandas while loading the data.
#
# To solved such error either use engine='python' or encoding='latin-1' options. I used encoding='latin-1'.
#
# For more details please visit to the site ("https://en.wikipedia.org/wiki/%C3%8F")

# %% [markdown]
# <a id=section302></a>
# ### 3.2 Understanding the Dataset

# %% [markdown]
# To gain insights from data we must look into each aspect of it very carefully. We will start with observing few rows and columns of data both from the starting and from the end

# %%
carsales_data.columns                                                  # This will print the names of all columns.
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')

# %% [markdown]
# This dataset contains data with __10 columns.__

# %%
carsales_data.shape                         # This will print the number of rows and comlumns of the Data Frame
# Out:
# (9576, 10)

# %% [markdown]
# This dataset has __9576 rows__ and __10 columns.__
#
# This dataset contains data for __9376 observations of 10 columns__ for cars sale. Most of them are used cars so it opens the possibility to analyze features related to car saling. This dataset is provided by INSAID for study/practice purposes

# %%
carsales_data.head()                                        # This will print the First n rows of the Data Frame
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0  Ford           15500.0  crossover  68       2.5   Gas     yes
# 1  Mercedes-Benz  20500.0  sedan      173      1.8   Gas     yes
# 2  Mercedes-Benz  35000.0  other      135      5.5   Petrol  yes
# 3  Mercedes-Benz  17800.0  van        162      1.8   Diesel  yes
# 4  Mercedes-Benz  33000.0  vagon      91      NaN    Other   yes
#
#    year    model  drive
# 0  2010  Kuga     full
# 1  2011  E-Class  rear
# 2  2008  CL 550   rear
# 3  2012  B 180    front
# 4  2013  E-Class  NaN

# %%
carsales_data.tail()                                        # This will print the last n rows of the Data Frame
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 9571  Hyundai        14500.0  crossover  140      2.0   Gas     yes
# 9572  Volkswagen     2200.0   vagon      150      1.6   Petrol  yes
# 9573  Mercedes-Benz  18500.0  crossover  180      3.5   Petrol  yes
# 9574  Lexus          16999.0  sedan      150      3.5   Gas     yes
# 9575  Audi           22500.0  other      71       3.6   Petrol  yes
#
#       year      model  drive
# 9571  2011  Tucson     front
# 9572  1986  Passat B2  front
# 9573  2008  ML 350     full
# 9574  2008  ES 350     front
# 9575  2007  Q7         full

# %% [markdown]
# <a id=section303></a>
# ### 3.3 Description of the Dataset

# %% [markdown]
# __Below is a table showing names of all the columns and their description.__
#
# | Column Name   | Description                                                   |
# | ------------- |:-------------------------------------------------------------:|
# | car           | Manufacturer Brand                                            |
# | price         | Seller’s price in advertisement (in USD)                      |
# | body          | Car Body Type                                                 |
# | mileage       | Represents rounded engine mileage (in ‘000 Km)                |
# | engV          | Represents rounded engine volume (in ‘000 cubic cm).          |
# | engType       | Type of fuel (“Other” in this case should be treated as NA)   |
# | registration  | Whether car registered or not                                 |
# | year          | Year of production                                            |
# | model         | Specific model name                                           |
# | drive         | Drive type                                                    |

# %%
carsales_data.dtypes
# Out:
# car             object
# price           float64
# body            object
# mileage         int64
# engV            float64
# engType         object
# registration    object
# year            int64
# model           object
# drive           object
# dtype: object

# %% [markdown]
# According to above staement this dataset having __four numerical columns__ and __six categorical columns__.

# %%
carsales_data.info()                                    # This will give Index, Datatype and Memory information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
# car             9576 non-null object
# price           9576 non-null float64
# body            9576 non-null object
# mileage         9576 non-null int64
# engV            9142 non-null float64
# engType         9576 non-null object
# registration    9576 non-null object
# year            9576 non-null int64
# model           9576 non-null object
# drive           9065 non-null object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %%
carsales_data.describe(include='all')
# Out:
#                car          price   body      mileage         engV engType  \
# count   9576        9576.000000    9576   9576.000000  9142.000000  9576
# unique  87         NaN             6     NaN          NaN           4
# top     Volkswagen NaN             sedan NaN          NaN           Petrol
# freq    936        NaN             3646  NaN          NaN           4379
# mean    NaN         15633.317316   NaN    138.862364   2.646344     NaN
# std     NaN         24106.523436   NaN    98.629754    5.927699     NaN
# min     NaN         0.000000       NaN    0.000000     0.100000     NaN
# 25%     NaN         4999.000000    NaN    70.000000    1.600000     NaN
# 50%     NaN         9200.000000    NaN    128.000000   2.000000     NaN
# 75%     NaN         16700.000000   NaN    194.000000   2.500000     NaN
# max     NaN         547800.000000  NaN    999.000000   99.990000    NaN
#
#        registration         year    model  drive
# count   9576         9576.000000  9576     9065
# ...

# %% [markdown]
# Here we can see that __engv__ and __drive__ columns have minimum values for count which is not making sense and indicates an invalid or missing value.

# %%
carsales_data.isnull().sum()
# Out:
# car             0
# price           0
# body            0
# mileage         0
# engV            434
# engType         0
# registration    0
# year            0
# model           0
# drive           511
# dtype: int64

# %% [markdown]
# From the above output we can see that __engV__ and __drive__ columns contains maximum null values. We will see how to deal with them.

# %%
total = carsales_data.isnull().sum().sort_values(ascending=False)
percent = (carsales_data.isnull().sum()/carsales_data.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
print(missing_data)
# Out:
#               Total   Percent
# drive         511    0.053363
# engV          434    0.045322
# model         0      0.000000
# year          0      0.000000
# registration  0      0.000000
# engType       0      0.000000
# mileage       0      0.000000
# body          0      0.000000
# price         0      0.000000
# car           0      0.000000

# %% [markdown]
# From the above output also we can see that only __engV__ and __drive__ columns contains maximum null values.

# %% [markdown]
# <a id=section304></a>
# ### 3.4 Pre Profiling

# %% [markdown]
# - By pandas profiling, an __interactive HTML report__ gets generated which contins all the information about the columns of the dataset, like the __counts and type__ of each _column_. Detailed information about each column, __coorelation between different columns__ and a sample of dataset.<br/>
# - It gives us __visual interpretation__ of each column in the data.
# - _Spread of the data_ can be better understood by the distribution plot.
# - _Grannular level_ analysis of each column.

# %%
profile = pandas_profiling.ProfileReport(carsales_data)
profile.to_file(output_file="carsales_data_before_preprocessing.html")

# %% [markdown]
# Here, we have done Pandas Profiling before preprocessing our dataset, so we have named the html file as __carsales_data_before_preprocessing.html__. Take a look at the file and see what useful insight we can develop from it. <br/>
# Now we will process our data to better understand it.

# %% [markdown]
# <a id=section306></a>
# ### 3.6 Initial observations:
# - Summary of data types in this dataset:
#  - <em>Numeric</em>: <strong>price</strong> (Float), <strong>Mileage</strong> (Integer), <strong>engV</strong> (Float), <strong>Year</strong> (Integer)
#  - <em>Boolean</em>: <strong>registration</strong>
#  - <em>Object</em>: Everything else
# - The following variables have null and zero values that may need to addressed.
#  - <strong>Car</strong> has a high cardinality __87 distinct values__.
#  - <strong>Drive</strong> has 511 (5.3%) missing values.
#  - <strong>Eng Volume</strong> has 434 (4.5%) missing values.
#  - <strong>Mileage</strong> has 348 (3.6%) zeros.
#  - <strong>Model</strong> has a high cardinality with 888 distinct values.
#  - <strong>Price</strong> has 267 (2.4%) zeros.

# %% [markdown]
# <a id=section306></a>
# ### 3.6 Final observations
#
# Variables to transform prior to analysis:
# - Standardize all column headers to lower case (to prevent typos!)
# - __Price__ & __Mileage__: Remove outliers as the columns have outlier as 0 and it is too low to be real value.
# - __Drive__ & __engV__: Replaced the null values with the column mean value.
# - __Car__ column looks good as we can expect 87 distinct values for Brand.
# - __Model__ seems not usefull for analysis and need to remove or ignore this column.
#
# It will be important to decide how to handle NaN values.

# %% [markdown]
# <a id=section4></a>
# ## 4. Data Normalization or Purification

# %% [markdown]
# <a id=section401></a>
# ### 4.1 Removal of Duplicates

# %%
carsales_data.drop_duplicates(keep=False, inplace=True)           # Removing duplicate rows
carsales_data.shape
# Out:
# (9375, 10)

# %% [markdown]
# This dataset has __201__ duplicate rows, which was removed here and now __9375__ unique rows are present in dataset.

# %% [markdown]
# <a id=section402></a>
# ### 4.2 Standardize all column headers to lower case

# %%
# map() function returns a list of results after applying the given function to each item of a given iterable.
carsales_data.columns = map(str.lower, carsales_data.columns) 
carsales_data.dtypes                                        # Confirm that all variable names are now lower case
# Out:
# car             object
# price           float64
# body            object
# mileage         int64
# engv            float64
# engtype         object
# registration    object
# year            int64
# model           object
# drive           object
# dtype: object

# %% [markdown]
# <a id=section403></a>
# ### 4.3 Handling categorical data & its imputation
#  - <strong>Drive</strong> has 511 (5.3%) missing values.

# %% [markdown]
# __Drive:__ Replacing missing values now for __drive__ column based on [car, model] group product and __mode__ value of __drive__ based on this group

# %%
print("How many values are NaN?: ", pd.isnull(carsales_data['drive']).sum())
# Out:
# How many values are NaN?:  509

# %% [markdown]
# From the above output we can see that price column has __509__ observation has __NULL__ value for __drive__ column. __2__ observation has been deleted while removing duplicate.

# %%
def get_drive_mode(x):
    brand = x.name[0]
    if x.count() > 0:
        return x.mode() # Return mode for a brand/model if the mode exists.
    elif carsales_data.groupby(['car'])['drive'].count()[brand] > 0:
        brand_mode = carsales_data.groupby(['car'])['drive'].apply(lambda x: x.mode())[brand]
        return brand_mode # Return mode of brand if particular brand/model combo has no mode,
    else:                 # but brand itself has a mode for the 'drive' feature. 
        return carsales_data['drive'].mode() # Otherwise return dataset's mode for the 'drive' feature.
    
drive_modes = carsales_data.groupby(['car','model'])['drive'].apply(get_drive_mode).reset_index().drop('level_2', 
                                                                                                       axis=1)
drive_modes.rename(columns={'drive': 'drive_mode'}, inplace=True)
drive_modes.head()
# Out:
#      car model drive_mode
# 0  Acura  MDX   full
# 1  Acura  RL    full
# 2  Acura  TL    front
# 3  Acura  TLX   front
# 4  Acura  ZDX   full

# %%
def fill_with_mode(x):
    if pd.isnull(x['drive']):
        return drive_modes[(drive_modes['car'] == x['car']) 
                           & (drive_modes['model'] == x['model'])]['drive_mode'].values[0]
    else:
        return x['drive']
    
carsales_data['drive'] = carsales_data.apply(fill_with_mode, axis=1)
carsales_data.head()
# Out:
#              car    price   body  mileage  engv engtype registration  year  \
# 2  Mercedes-Benz  35000.0  other  135      5.5   Petrol  yes          2008
# 4  Mercedes-Benz  33000.0  vagon  91      NaN    Other   yes          2013
# 6  Honda          6500.0   sedan  199      2.0   Petrol  yes          2003
# 8  Mercedes-Benz  21500.0  sedan  146      1.8   Gas     yes          2012
# 9  Mercedes-Benz  22700.0  sedan  125      2.2   Diesel  yes          2010
#
#      model  drive
# 2  CL 550   rear
# 4  E-Class  rear
# 6  Accord   front
# 8  E-Class  rear
# 9  E-Class  rear

# %% [markdown]
# <a id=section404></a>
# ### 4.4 Handling numerical data & imputation
# - <strong>Eng Volume</strong> has 434 (4.5%) missing values.
# - <strong>Mileage</strong> has 348 (3.6%) zeros.
# - <strong>Price</strong> has 267 (2.8%) zeros.

# %% [markdown]
# __Eng Volume:__ Replacing missing values now for __engv__ column based on [car, model] group product and __median__ value of __engv__ based on this group.

# %%
print("How many values are NaN?: ", pd.isnull(carsales_data['engv']).sum())
# Out:
# How many values are NaN?:  434

# %% [markdown]
# From the above output we can see that price column has __434__ observation has __NaN__ value for __engv__ column.

# %%
def get_median_engv(x):
    brand = x.name[0]
    if x.count() > 0:
        return x.median() # Return median for a brand/model if the median exists.
    elif carsales_data.groupby(['car'])['engv'].count()[brand] > 0:
        brand_median = carsales_data.groupby(['car'])['engv'].apply(lambda x: x.median())[brand]
        return brand_median # Return median of brand if particular brand/model combo has no median,
    else:                 # but brand itself has a median for the 'engV' feature. 
        return carsales_data['engv'].median() # Otherwise return dataset's median for the 'engV' feature.
    
engV_median = carsales_data.groupby(['car','model'])['engv'].apply(get_median_engv).reset_index()
engV_median.rename(columns={'engv': 'engv_med'}, inplace=True)
engV_median.head()
# Out:
#      car model  engv_med
# 0  Acura  MDX   3.7
# 1  Acura  RL    3.5
# 2  Acura  TL    3.2
# 3  Acura  TLX   2.4
# 4  Acura  ZDX   3.7

# %%
def fill_with_median(x):
    if pd.isnull(x['engv']):
        return engV_median[(engV_median['car'] == x['car']) 
                           & (engV_median['model'] == x['model'])]['engv_med'].values[0]
    else:
        return x['engv']
    
carsales_data['engv'] = carsales_data.apply(fill_with_median, axis=1)
carsales_data.head()
# Out:
#              car    price   body  mileage  engv engtype registration  year  \
# 2  Mercedes-Benz  35000.0  other  135      5.5   Petrol  yes          2008
# 4  Mercedes-Benz  33000.0  vagon  91       2.6   Other   yes          2013
# 6  Honda          6500.0   sedan  199      2.0   Petrol  yes          2003
# 8  Mercedes-Benz  21500.0  sedan  146      1.8   Gas     yes          2012
# 9  Mercedes-Benz  22700.0  sedan  125      2.2   Diesel  yes          2010
#
#      model  drive
# 2  CL 550   rear
# 4  E-Class  rear
# 6  Accord   front
# 8  E-Class  rear
# 9  E-Class  rear

# %% [markdown]
# __Price:__ Replacing missing values now for __price__ column based on [car, model] group product and __median__ value of __price__ based on this group.

# %%
print("Minimum price: ", carsales_data["price"].min())
print("Maximum price: ", carsales_data["price"].max())
print("How many values are NaN?: ", pd.isnull(carsales_data['price']).sum())
print("How many values are 0? : ", carsales_data.price[carsales_data.price == 0].count())
# Out:
# Minimum price:  0.0
# Maximum price:  547800.0
# How many values are NaN?:  0
# How many values are 0? :  224

# %% [markdown]
# From the above output we can see that price column has __267__ observation has __zero__ value for __price__ column. __43__ observation has been deleted while removing duplicate.

# %%
carsales_data['price'] = carsales_data['price'].replace(0,np.nan)       # This will replace zero value with NaN

# %%
# This will replace NaN with mean
carsales_data['price'].fillna(carsales_data.groupby(['car', 'model'])['price'].transform('median'),inplace=True)

# %%
carsales_data[carsales_data['price'].isnull()]  # Check the observation for NaN value after replacing
# Out:
#                 car  price       body  mileage  engv engtype registration  \
# 3280  Hyundai       NaN     sedan      27       5.00  Petrol  yes
# 3335  ËUAZ          NaN     other      10       1.50  Petrol  yes
# 4038  GAZ           NaN     other      1        2.46  Other   yes
# 5084  GAZ           NaN     crossover  1        2.46  Petrol  yes
# 6248  GMC           NaN     crossover  130      4.30  Petrol  yes
# 7220  VAZ           NaN     hatch      1        1.50  Gas     yes
# 7848  Mercedes-Benz NaN     van        273      2.90  Diesel  yes
# 8772  BMW           NaN     sedan      99       4.40  Petrol  yes
# 8824  Fisker        NaN     other      100      2.00  Other   yes
#
#       year               model  drive
# 3280  2013  Genesis             rear
# 3335  1991  969 Âîëûíü          full
# 4038  1958  69                  full
# 5084  1963  69                  full
# 6248  1998  Safari              full
# 7220  1998  2109 (Áàëòèêà)      front
# ...

# %% [markdown]
# From the above output we can see that multiple rows still having zero value for price column, it means median is not calculated with respect to [car, model]. Replacing missing values now for __price__ column based on [car] group product and __median__ value of __price__ based on this group.

# %%
# This will replace NaN with median
carsales_data['price'].fillna(carsales_data.groupby('car')['price'].transform('median'),inplace=True)

# %%
carsales_data[carsales_data['price'].isnull()]  # Check the observation for NaN value after replacing
# Out:
#          car  price   body  mileage  engv engtype registration  year  model  \
# 8824  Fisker NaN     other  100      2.0   Other   yes          2001  Karma
#
#       drive
# 8824  front

# %% [markdown]
# - From the above output we can see that, still we have 1 observation with null value for __price__ column, after replacing null values with median.
# - This observation still exist with null value, because we had only 1 observation for car brand __Fisker__ with zero price in our dataset before processing the data.
# - I found price of car brand __Fisker__ about __$169000__ & i am going to replace with it.

# %%
# This will drop the observation which has null value of price
carsales_data['price'].fillna(169000.00,inplace=True)

# %% [markdown]
# __Mileage:__ Replacing missing values now for __mileage__ column based on [car, model, year] group product and __median__ value of __mileage__ based on this group. Year has been included here as per data observations year to year mileage is getting down for the same Car/Brand combination.

# %%
print("Minimum Mileage: ", carsales_data["mileage"].min())
print("Maximum Mileage: ", carsales_data["mileage"].max())
print("How many values are NaN?: ", pd.isnull(carsales_data['mileage']).sum())
print("How many values are 0? : ",carsales_data.price[carsales_data.mileage == 0].count())
# Out:
# Minimum Mileage:  0
# Maximum Mileage:  999
# How many values are NaN?:  0
# How many values are 0? :  285

# %% [markdown]
# From the above output we can see that price column has __285__ observation has __zero__ value for __mileage__ column. __63__ observation has been deleted while removing duplicate.

# %%
carsales_data['mileage'] = carsales_data['mileage'].replace(0,np.nan)   # This will replace zero value with NaN

# %%
# This will replace NaN with median
carsales_data['mileage'].fillna(carsales_data.groupby(['car', 'model', 'year'])['mileage']
                                .transform('median'),inplace=True)

# %%
carsales_data[carsales_data['mileage'].isnull()]  # Check the observation for NaN value after replacing
# Out:
#                 car         price       body  mileage  engv engtype  \
# 10    Nissan         20447.15400   crossover NaN       1.20  Petrol
# 92    Audi           36000.00000   crossover NaN       3.00  Diesel
# 93    Audi           88888.00000   crossover NaN       3.00  Diesel
# 236   Nissan         25382.95500   crossover NaN       1.60  Diesel
# 285   Kia            42741.62100   crossover NaN       2.20  Diesel
# 425   Nissan         15656.58900   crossover NaN       1.60  Petrol
# 460   Land Rover     79450.00000   other     NaN       3.50  Diesel
# 470   Subaru         29500.00000   crossover NaN       2.50  Petrol
# 484   Hyundai        39900.00000   crossover NaN       2.20  Diesel
# 501   Hyundai        37400.00000   crossover NaN       2.20  Diesel
# 504   Peugeot        17895.15000   hatch     NaN       1.60  Diesel
# 578   Hyundai        21166.66500   sedan     NaN       1.80  Petrol
# 637   Bentley        222222.00000  other     NaN       6.00  Petrol
# ...

# %% [markdown]
# - From the above output we can see that, still we have 123 observation with null values for __mileage__ column, after replacing null values with median.

# %%
# This will replace NaN with median
carsales_data['mileage'].fillna(carsales_data.groupby(['car', 'model'])['mileage'].transform('median')
                                ,inplace=True)

# %%
carsales_data[carsales_data['mileage'].isnull()]  # Check the observation for NaN value after replacing
# Out:
#                 car         price       body  mileage  engv engtype  \
# 2004  Mercedes-Benz  142499.00000  crossover NaN       4.70  Petrol
# 3285  Mercedes-Benz  129999.00000  crossover NaN       4.67  Petrol
# 3411  Mercedes-Benz  154999.00000  crossover NaN       4.60  Petrol
# 4464  Mercedes-Benz  124000.00000  crossover NaN       3.00  Petrol
# 4466  Mercedes-Benz  58999.00000   crossover NaN       2.20  Diesel
# 4857  Renault        17639.46795   crossover NaN       1.20  Petrol
# 5924  VAZ            7035.79500    sedan     NaN       1.60  Petrol
# 5933  Renault        13321.32750   crossover NaN       1.50  Diesel
# 5985  Renault        20996.23500   crossover NaN       1.50  Diesel
# 6610  Mercedes-Benz  62999.00000   crossover NaN       2.20  Diesel
# 7499  Mercedes-Benz  124000.00000  crossover NaN       3.00  Petrol
# 7621  Bentley        547800.00000  sedan     NaN       6.75  Petrol
# 8023  Mercedes-Benz  60999.00000   crossover NaN       2.20  Diesel
# ...

# %%
# This will replace NaN with median
carsales_data['mileage'].fillna(carsales_data.groupby(['car'])['mileage'].transform('median'),inplace=True)

# %%
carsales_data[carsales_data['mileage'].isnull()]  # Check the observation for NaN value after replacing
# Out:
# Empty DataFrame
# Columns: [car, price, body, mileage, engv, engtype, registration, year, model, drive]
# Index: []

# %%
carsales_data.price[carsales_data.mileage == 0].count()
# Out:
# 0

# %% [markdown]
# From the above output we can see that, now __mileage__ column does not have any null value

# %%
carsales_data.isnull().sum()
# Out:
# car             0
# price           0
# body            0
# mileage         0
# engv            0
# engtype         0
# registration    0
# year            0
# model           0
# drive           0
# dtype: int64

# %% [markdown]
# We can see there are no missing data exist in our dataset.

# %% [markdown]
# <a id=section405></a>
# ### 4.5 Post Profiling

# %%
profile = pandas_profiling.ProfileReport(carsales_data)
profile.to_file(output_file="carsales_data_postprocessing.html")

# %%
carsales_data.describe(include='all')
# Out:
#                car          price   body      mileage         engv engtype  \
# count   9375        9375.000000    9375   9375.000000  9375.000000  9375
# unique  87         NaN             6     NaN          NaN           4
# top     Volkswagen NaN             sedan NaN          NaN           Petrol
# freq    919        NaN             3601  NaN          NaN           4309
# mean    NaN         15683.280058   NaN    142.656427   2.618964     NaN
# std     NaN         23064.306395   NaN    97.262677    6.026570     NaN
# min     NaN         259.350000     NaN    1.000000     0.100000     NaN
# 25%     NaN         5400.000000    NaN    75.000000    1.600000     NaN
# 50%     NaN         9500.000000    NaN    130.000000   2.000000     NaN
# 75%     NaN         16800.000000   NaN    197.000000   2.500000     NaN
# max     NaN         547800.000000  NaN    999.000000   99.990000    NaN
#
#        registration         year    model  drive
# count   9375         9375.000000  9375     9375
# ...

# %% [markdown]
# We have processed the data and now the dataset does not contain any missing values. So, the pandas profiling report which we have generated after preprocessing will give us more beneficial insights.
# observations:
#
# - In the Dataset info, __Total Missing(%) = 0.0%__
# - Number of variables = 10

# %%
sns.heatmap(carsales_data.corr(),annot=True, linewidths=.5)
plt.title("Heatmap for Highest correlated features for Carsale datset")
# Out:
# Text(0.5, 1, 'Heatmap for Highest correlated features for Carsale datset')

# %% [markdown]
# By this heatmap we can say that -
# - __price__ and __production year__ variables have __strong positive correlation__, i.e. latest production year cars have high  price and older production year cars have lower price.
# - __price and engine volume (engV)__ have __mild positive correlation__.
# - __engine volume (engV) and mileage__ also have some __mild positive correlation__, generally engine volume and mileage do not have positive correlation, but in our data most of the cars have engine volume in between 1.5 CC to 2.5 CC, due to that mileage and engine volume have mild positive correlation.
# - __production year__ and __mileage__ variables have __strong negative correlation__, i.e. latest production year cars have high mileage and older production year cars have low mileage.
# - __price and mileage__ have __negative correlation__, i.e. lower price cars have higher mileage and higher price cars have lower mileage.
# - __production year and engine volume (engV)__ also have some __negative correlation__.

# %% [markdown]
# <a id=section5></a>
# ## 5. Analysis & Identify patterns in the data
#
# - Here we have categorized the whole analysis in three major below mentioned categories.
#     + Univariate
# 	+ Bivariate
# 	+ Multivariate

# %%
cardata = carsales_data.copy()
cardata.columns
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engv', 'engtype', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')

# %% [markdown]
# <a id=section501></a>
# ## 5.1 Univariate Analysis
#
# Univariate analysis is the simplest form of analyzing data. “Uni” means “one”, so in other words your data has only one variable. It doesn't deal with causes or relationships (unlike regression) and it's major purpose is to describe; it takes data, summarizes that data and finds patterns in the data.

# %% [markdown]
# <a id=section50101></a>
# ## 5.1.1 Which brand of cars sold the most of the car?

# %%
# top 20 brands which cars sold the most
chart = sns.countplot(x = 'car', data = cardata, order = cardata['car'].value_counts()
                      .nlargest(20).index)
chart.set_xticklabels(chart.get_xticklabels(), rotation=75)

# Add this loop to add the annotations
for p in chart.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_x(), p.get_y() 
    chart.annotate('{:1}'.format(height), (x + 0.2, y + height - 30), fontsize=12,
                color='white')
    
plt.title("Count of sold cars by brand", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Brand', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Number of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});
plt.show()

# %% [markdown]
# The most cars sold by the company __Volkswagen__ followed by __Mercedes-Benz__ and __BMW__.

# %% [markdown]
# <a id=section50102></a>
# ## 5.1.2 Which price range of cars sold the most of the car?

# %%
cardata['price'].min()
# Out:
# 259.35

# %%
cardata['price'].max()
# Out:
# 547800.0

# %% [markdown]
# This dataset has minimum price of car as __259.35__ and maximum price as __547800__, so we can create a new field __price_group__ and update it with 5 to 6 price groups.

# %%
# Create a new column 'price_group' and assign the value based on car price
cardata['price_group'] = pd.cut(cardata['price'],[0,20000,40000,60000,80000,100000,600000], 
                                labels = ['<20K','20-39K','40-59K','60-79K','80-99K','>100K'], 
                                include_lowest = True)
cardata['price_group'] = cardata['price_group'].astype(object)

# %%
ax = (cardata['price_group'].value_counts() / len(cardata) *100).plot.bar()
plt.xticks(rotation=45)
plt.title("Count of sold cars by price group", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('% of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Price Group', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:.0%}'.format(height / 100), (x + 0.1, y + height - 5), fontsize=22,
                color='white')

# %% [markdown]
# Approx __81%__ of cars sold in the __price range of less than or equal to $20000__.

# %% [markdown]
# <a id=section50103></a>
# ## 5.1.3 Which body type of cars sold the most of the car?

# %%
chart = sns.countplot(cardata['body'])                    # Bar chart for car 'body' variable
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.title("Count of sold cars by body type", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Number of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Body type', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# Add this loop to add the annotations
for p in chart.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_x(), p.get_y() 
    chart.annotate('{:1}'.format(height), (x + 0.2, y + height - 200), fontsize=22,
                color='white')

# %% [markdown]
# __"Sedan"__ body type cars are the most sold cars.
#
# Lets see it in terms of % it in below chart. We can say this in other terms that the most preferred choice for people is __Sedan__, because it is the perfect and comfortable car for small size family within lower budget.

# %%
# Bar chart of car 'body in terms of %'
ax =  ((cardata['body'].value_counts() / len(cardata)) * 100).plot.bar()
plt.xticks(rotation=45)
plt.title("Percenyage of sold cars by body type", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('% of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Body type', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:.0%}'.format(height / 100), (x + 0.1, y + height - 2), fontsize=22,
                color='white')

# %% [markdown]
# Approx 38% of total cars sold in __Sedan__ body type, 21% in __Crossover__ body type and 13% in __Hatch__ body type.

# %% [markdown]
# Sedan are most preferred private cars among public vehicles vans are preferred.

# %% [markdown]
# <a id=section50104></a>
# ## 5.1.4 What is variation of the car sold in terms of mileage of the car?

# %%
cardata['mileage'].min()
# Out:
# 1.0

# %%
cardata['mileage'].max()
# Out:
# 999.0

# %%
# Create a new column 'mileage_group' and assign the value based on car price
cardata['mileage_cat'] = pd.cut(cardata.mileage, [0,200,400,600,800,1000], 
                                      labels=['<200','200-400','400-600','600-800','800+'],  include_lowest=True)
cardata['mileage_cat'] = cardata['mileage_cat'].astype(object)

# %%
cardata.columns = map(str.lower, cardata.columns) 
mileage_avg = sum(cardata['mileage']) / len(cardata['mileage'])
cardata['mileage_level'] = ["high mileage" if i > mileage_avg else "low mileage" 
                                  for i in cardata['mileage']]

# %%
ax = cardata['mileage_cat'].value_counts().plot.bar()
plt.xticks(rotation=45)
plt.title("Count of sold cars by mileage group", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Number of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Mileage Group', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:1}'.format(height), (x + 0.1, y + height - 200), fontsize=12,
                color='white')

# %%
ax = sns.countplot(cardata['mileage_level']) 
plt.xticks(rotation=45)
plt.title("Count of sold cars by mileage levels", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Number of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Mileage Level', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:1}'.format(height), (x + 0.3, y + height - 200), fontsize=22,
                color='white')

# %% [markdown]
# __Low__ mileage vehicles are prefered.

# %% [markdown]
# <a id=section50105></a>
# ## 5.1.5 Which engine volume cars sold the most of the car?

# %%
# grouping of engV  
ax = (pd.cut(cardata['engv'],[0,0.51,1.51,2.51,3.51,100], 
        labels = ['<=0.5','0.51-1.50','1.51-2.50','2.51-3.50','>3.51'])
 .value_counts() / len(cardata)*100).plot.bar()    

plt.xticks(rotation = 25)
plt.title("Count of sold cars by engine volume group", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('% of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Engine Volume Group', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:.0%}'.format(height / 100), (x + 0.1, y + height - 2), fontsize=22,
                color='white')

# %% [markdown]
# Below are the __top three categories__ of __Engine Volume (engV)__ cars sold.
# - __Ist Category__   : > 1.5 & <= 2.5 (In this category approx __56%__ of cars are available)
# - __IInd Category__  : > 0.5 & <= 1.5 (In this category approx __21%__ of cars are available)
# - __IIIrd Category__ : > 2.5 & <= 3.5 (In this category approx __14%__ of cars are available)
#
# Out of total cars sold, approx __91%__ cars fall in range of engine volume more than __1.5 CC to  3.5 CC__.

# %%
# engine volume wise count of vehicles
careng = cardata.loc[cardata['engv'] <= 6]
careng['engv'].value_counts().sort_index().plot.line()
plt.title("Count of sold cars by engine volume (CC)", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Number of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Engine Volume', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# %% [markdown]
# Most of the cars sold have __2.0 CC__ engine volume followed by __1.5 CC__, there are very __few cars sold__ with engine volume __less than equal to 1.0 CC and greater than equal to 4.0 CC__.

# %% [markdown]
# <a id=section50106></a>
# ## 5.1.6 Which engine type cars sold the most of the car?

# %%
ct = pd.value_counts(cardata['engtype'].values, sort=False)
labels = cardata['engtype'].unique()
labels.sort()
sizes = ct
ct.sort_index(inplace=True)
colors = ['red', 'pink', 'green', 'blue']
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.axis('equal')
plt.show()

# %% [markdown]
# __Petrol & Diesel__ cars are the most widely sold Engine Type. Gas and Other fuels are not so commonly used.

# %% [markdown]
# <a id=section50107></a>
# ## 5.1.7 What is effect of the car sold in terms of registration of the car?

# %%
#cardata['registration'].value_counts().plot(kind = 'bar')
ax = sns.countplot(cardata['registration']) 
plt.xticks(rotation=45)
plt.title("Count of sold cars by registration", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Number of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Registration', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:1}'.format(height), (x + 0.3, y + height - 300), fontsize=22,
                color='white')

# %% [markdown]
# __Registered__ vehicles are prefered.

# %% [markdown]
# <a id=section50108></a>
# ## 5.1.8 In which production year of cars sold the most of the car?

# %%
chart = cardata['year'].value_counts().head(10).plot.bar()
plt.xticks(rotation=45)
plt.title("Count of sold cars by production years", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Number of sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Production Years', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# Add this loop to add the annotations
for p in chart.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_x(), p.get_y() 
    chart.annotate('{:1}'.format(height), (x + 0.1, y + height - 40), fontsize=12,
                color='white')

# %%
# production year wise count of vehicles
caryr = cardata.loc[cardata['year'] >= 2000]
caryr['year'].value_counts().sort_index().plot.line()
plt.title("Count of sold cars by production years", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Number of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Production Years', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# %% [markdown]
# __Production year 2008 and 2012__ cars are sold the most. Year __2008__ has the highest number of car sales record.

# %% [markdown]
# <a id=section50109></a>
# ## 5.1.9 Which model type of cars sold the most of the car of the car?

# %%
# production year wise count of vehicles
chart = cardata['model'].value_counts().head(10).plot.bar()
plt.title("Count of sold cars by model", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Count of vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Model', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});
plt.xticks(rotation=45)

# Add this loop to add the annotations
for p in chart.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_x(), p.get_y() 
    chart.annotate('{:1}'.format(height), (x + 0.1, y + height - 4), fontsize=12,
                color='white')

# %% [markdown]
# __E-Class__ car sold most.

# %% [markdown]
# <a id=section501010></a>
# ## 5.1.10 Which drive type of cars sold the most of the car?

# %%
# Pie chart of car 'drive' type
ct = pd.value_counts(cardata['drive'].values, sort=False)
labels = cardata['drive'].unique()
labels.sort()
sizes = ct
ct.sort_index(inplace=True)
explode = (0, 0, 0.05)
plt.pie(sizes, explode=explode, labels=labels, autopct='%.2f%%', pctdistance=0.6, shadow=True, startangle=140)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.title("Percentage of sold cars by drive type", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.axis('equal')
plt.show()

# %%
carsales_data['drive'].value_counts().plot(kind='bar')
chart = cardata['drive'].value_counts().plot.bar()
plt.xticks(rotation=45)
plt.title("Count of sold cars by drive type", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Number of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Drive Type', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# Add this loop to add the annotations
for p in chart.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_x(), p.get_y() 
    chart.annotate('{:1}'.format(height), (x + 0.15, y + height - 200), fontsize=22,
                color='white')

# %% [markdown]
# Most sold cars in __front__ drive type, in terms of percentage we can say that, approx 59% of total cars sold in __front__ drive type, 26.09% in __full__ drive type and 15.60% in __rear__ drive type.

# %% [markdown]
# <a id=section502></a>
# ## 5.2 Bivariate Analysis
#
# Bivariate analysis means the analysis of bivariate data. It is one of the simplest forms of statistical analysis, used to find out if there is a relationship between two sets of values. It usually involves the variables X and Y.

# %% [markdown]
# <a id=section50201></a>
# ## 5.2.1 Which model is the most prefered in top brands of the car?

# %%
usa = cardata.loc[cardata['car'] == 'Volkswagen']
top_10_model = usa['model'].value_counts()[:10].to_frame()
sns.barplot(top_10_model['model'], top_10_model.index)
plt.title('Top 10 Volkswagen models in terms of contribution', 
          fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Indices', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});
plt.ylabel('Model Name', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# %%
usa1 = cardata.loc[cardata['car'] == 'Mercedes-Benz']
top_10_model1 = usa1['model'].value_counts()[:10].to_frame()
sns.barplot(top_10_model1['model'], top_10_model1.index)
plt.title('Top 10 Mercedes-Benz model in terms of contribution', 
          fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Indices', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});
plt.ylabel('Model Name', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# %% [markdown]
# __Passat & E-Class__ is the most prefered model in __Volkswagen and Mercedes-Benz__ companies respectively.

# %% [markdown]
# <a id=section50202></a>
# ## 5.2.2 Which drive type is the most prefered in top brands of the car?

# %%
usa = cardata.loc[cardata['car'] == 'Volkswagen']
top_10_model = usa['drive'].value_counts()[:].to_frame()
sns.barplot(top_10_model['drive'], top_10_model.index, palette="PuBuGn_d")
plt.title('Volkswagen car drive types in terms of contribution', 
          fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Indices', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});
plt.ylabel('Drive Type', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# %%
usa = cardata.loc[cardata['car'] == 'Mercedes-Benz']
top_10_model = usa['drive'].value_counts()[:].to_frame()
sns.barplot(top_10_model['drive'], top_10_model.index, palette="PuBuGn_d")
plt.title('Mercedes-Benz car drive types in terms of contribution', 
          fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Indices', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});
plt.ylabel('Drive Type', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# %% [markdown]
# __Front and rear__ drive is most preferred in __Volkswagen and Mercedes-Benz__ companies respectively.

# %% [markdown]
# <a id=section50203></a>
# ## 5.2.3 Which fuel type is the most prefered in top brands of the car?

# %%
usa = carsales_data.loc[carsales_data['car'] == 'Mercedes-Benz']
top_10_model = usa['engtype'].value_counts()[:].to_frame()
sns.barplot(top_10_model['engtype'], top_10_model.index, palette="PuBuGn_d")
plt.title('Mercedes-Benz car fuel types in terms of contribution', 
          fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Indices', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});
plt.ylabel('Fuel Type', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# %%
usa = cardata[cardata['car'] == 'Volkswagen']
top_10_model = usa['engtype'].value_counts()[:].to_frame()
plt.figure()
sns.barplot(top_10_model['engtype'],top_10_model.index,palette="PuBuGn_d")
plt.title('Volkswagen car fuel types in terms of contribution', 
          fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Indices', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});
plt.ylabel('Fuel Type', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# %% [markdown]
# __Diesel engines__ are most preferred in __Volkswagen and Mercedes-Benz__ car companies.

# %% [markdown]
# <a id=section50204></a>
# ## 5.2.4 Average price of vehicle by brands?

# %%
# Brand wise car sale in higher price segment
carprc = cardata.loc[cardata['price'] >= 100000]
ax = (carprc['car'].value_counts() / len(carprc)*100).plot.bar()      # Bar chart of car 'body in terms of %'
plt.xticks(rotation = 105)
plt.title("Brand wise Sales Distribution in Higher Price Segment", 
          fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('% of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Brand Type', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:.0%}'.format(height / 100), (x + 0.1, y + height - 1), fontsize=10,
                color='white')

# %% [markdown]
# __Mercedes-Benz__ is the leading brand in higher price segment cars.

# %% [markdown]
# <a id=section50205></a>
# ## 5.2.5 Average price of vehicle by body type?

# %%
# body type v/s price group
sns.countplot(x='price_group',data=cardata, hue='body', 
              order=['<20K','20-39K','40-59K','60-79K','80-99K','>100K'])           
plt.title("Price Group v/s Body Type", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Price Group', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Number of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# %% [markdown]
# - The most cars sold in price range of __less than 20000__ and majority of these are in __Sedan__  body type.
# - The majority is __Crossover__ body type in Cars sold at a price __20000 or above__.

# %% [markdown]
# <a id=section50206></a>
# ## 5.2.6 Average price of vehicle by drive type?

# %%
# drive type v/s price group
sns.countplot(x='price_group',data=cardata, hue='drive', 
              order=['<20K','20-39K','40-59K','60-79K','80-99K','>100K'])
plt.title("Price Group v/s Drive Type", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Price Group', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Number of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# %% [markdown]
# - The most cars sold in price range of __less than 20000__ and majority of these are in __Front__  drive type.
# - The majority is __Full__ drive type in Cars sold at a price __20000 or above__.

# %% [markdown]
# <a id=section50207></a>
# ## 5.2.7 Average price of vehicle by mileage?

# %%
# price v/s mileage 
cardata[cardata['price'] < 100000 ].plot.scatter(x='price', y='mileage')
plt.title("Price v/s Mileage", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Mileage', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Price', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# __Price__ and __mileage__ have __strongly negative correlation__ in sold car dataset , i.e. lower price segment has higher mileage and higher price segment has lower mileage.

# %% [markdown]
# <a id=section50208></a>
# ## 5.2.8 Average price of vehicle by fuel type?

# %%
#Average price of vehicle by fuel type

# barplot for price based on fuel type and gearbox type
fig, ax = plt.subplots()
colors = ["#00e600", "#ff8c1a","#a180cc"]
sns.barplot(x="engtype", y="price", palette="husl",data=cardata)
ax.set_title("Average price of vehicles by fuel type", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.xaxis.set_label_text("Type Of Fuel", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.yaxis.set_label_text("Average Price", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
# Out:
# Text(0, 0.5, 'Average Price')

# %% [markdown]
# __Diesel__ vehicles are highly priced than __Petrol__ and __Gas__.

# %% [markdown]
# <a id=section50209></a>
# ## 5.2.9  Most preferred registration mode over the years of the car?

# %%
# Production year v/s registration
cc = cardata.loc[cardata['year'] >= 2000]
ax = sns.factorplot('year', data=cc, aspect=2.5, kind='count', hue='registration', color="b")
ax.set_xticklabels(rotation=30)

# %% [markdown]
# Majority of the cars sold with __production year 2008 or later__ were __registered__.

# %% [markdown]
# <a id=section50210></a>
# ## 5.2.10 Most prefered drive type with mileage of the car?

# %%
fig, ax = plt.subplots()
sns.countplot(data = cardata, x = 'mileage_cat', hue = 'drive')
plt.title('Mileage vs Car drive', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Number of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Mileage Group', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# %% [markdown]
# __Front drive__ cars are most prefered because of the high mileage they provide followed by __Full drive__ car with very low mileage(<200).

# %% [markdown]
# <a id=section50211></a>
# ## 5.2.11 Most prefered drive type with body type of the car?

# %%
# Body type and Drive type analysis
ax = sns.countplot(x='body',data=cardata, hue='drive')
plt.title("Body Type v/s Drive Type", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Body Type', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Number of the sold vehicles', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:1}'.format(height), (x + 0.12, y + height - 20), fontsize=10,
                color='white', ha='center', va='top')

# %% [markdown]
# - __Front__ drive cars are the top most cars in all body type except in __Crossover__ body type.
# - In __Crossover__ body type __Full__ drive cars are leading.

# %% [markdown]
# <a id=section50212></a>
# ## 5.2.12 Most prefered engine volume with mileage of the car?

# %%
# engV v/s mileage
cardata[cardata['engv'] < 3.51].plot.hexbin(x='engv', y='mileage', sharex=False, gridsize=12)
plt.title("Engine Volume v/s Mileage", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel('Mileage', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.xlabel('Engine Volume', fontdict={'fontsize': 'medium', 'fontweight': 'heavy'});

# %% [markdown]
# Most of the cars sold with __engine volume (engV)__ as 1.5 CC and __mileage__ as approx 200.

# %% [markdown]
# <a id=section503></a>
# ## 5.3 Multivariate Analysis
#
# Multivariate statistics concerns understanding the different aims and background of each of the different forms of multivariate analysis, and how they relate to each other. The practical application of multivariate statistics to a particular problem may involve several types of univariate and multivariate analyses in order to understand the relationships between variables and their relevance to the problem being studied.

# %% [markdown]
# <a id=section50301></a>
# ## 5.3.1 Pair Plot - What all variables paired with all the other variables of the car?

# %%
sns.pairplot(cardata, hue='engtype', palette="viridis", height=5)

# %% [markdown]
# - Price varying based on __Year__ and __Mileage__
# - As __Year__ increases there is increase in __Petrol__ engine type vehicles's prices which also depending on __mileage__ too.
# - Majority of the cars with __production year 2008 or later__ sold in __price 50000 or lower__.
# - All the cars with __production year 2010 or later__ sold in __price more than 50000__.
# - All the cars with __production year before 2010__ sold in __price 50000 or lower__.
# - The most cars sold in price range of __less than 20000__ and majority of these are in __Petrol__ engine type.
# - The majority is __Diesel__ engine type in Cars sold at a price __20000 or above__.
# - Mileage and price are indirectly related. high priced cars give low mileage.

# %% [markdown]
# <a id=section50302></a>
# ## 5.3.2 Average price of vehicle by body type and drive type of the car?

# %%
# Average price of vehicles by body type and drive type
fig, ax = plt.subplots()
colors = ["#00e600", "#ff8c1a","#a180cc"]
sns.barplot(x="body", y="price",hue="drive", palette=colors, data=cardata)
ax.set_title("Average price of cars by body type and drive type", 
             fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.xaxis.set_label_text("Body Type Of Car", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.yaxis.set_label_text("Average Price", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.show()

# %% [markdown]
# __All body types__ of cars have __more average price__ for __full drive type__ cars compare to __other drive types__.

# %% [markdown]
# <a id=section50303></a>
# ## 5.3.3 Average price of vehicle by engine type and drive type of the car?

# %%
# barplot for price based on engine type and drive type
colors = ["#00e600", "#ff8c1a","#a180cc"]
ax = sns.barplot(x="engtype", y="price", hue="drive", palette="husl", data=cardata)
ax.set_title("Average price of Cars by engine type and drive type", 
             fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.xaxis.set_label_text("Engine Type", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.yaxis.set_label_text("Average Price", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
# Out:
# Text(0, 0.5, 'Average Price')

# %% [markdown]
# The cars sold in __all engine type__ have __more average price__ for __full drive type__ cars compare to __other drive type__ cars.

# %% [markdown]
# <a id=section50304></a>
# ## 5.3.4 Average price of vehicle by mileage and registration of the car?

# %%
ax = sns.boxplot(x='registration',y='price',hue='mileage_level',data=cardata)
ax.set_title("Average price of vehicle by mileage and registration", 
             fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.xaxis.set_label_text("Registration Mode", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.yaxis.set_label_text("Average Price", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
# Out:
# Text(0, 0.5, 'Average Price')

# %% [markdown]
# __High mileage__ cars are __low priced__ and vise-versa.

# %% [markdown]
# <a id=section50305></a>
# ## 5.3.5 Average price of vehicle by vehicles by fuel type and drive?

# %%
fig, ax = plt.subplots()
colors = ["#00e600", "#ff8c1a","#a180cc"]

sns.barplot(x="engtype", y="price", hue= "drive", palette="husl",data=cardata)
ax.set_title("Average price of vehicles by fuel type and drive", 
             fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.xaxis.set_label_text("Type Of Fuel", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.yaxis.set_label_text("Average Price", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ticks = plt.setp(ax.get_xticklabels(),rotation=45)

# %% [markdown]
# __Full drive__ cars of all engine type cars are high priced compared to other fuel types followed by the __Rear drive__ cars in all fuel types.
#
# In Petrol and Diesel Front drive cars are almost equally priced.

# %% [markdown]
# <a id=section50306></a>
# ## 5.3.6 Average price of vehicle by mileage and drive of the car?

# %%
ax = sns.violinplot(x="drive", y="price",hue='mileage_level', palette="gnuplot", data=cardata)
plt.xlabel("Drive Type", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel("Price", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.title("Car drive Vs. price", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
# Out:
# Text(0.5, 1.0, 'Car drive Vs. price')

# %% [markdown]
# In all the car drive types, low mileage car are highly priced. where as the high mileage cars are priced low.

# %% [markdown]
# <a id=section50307></a>
# ## 5.3.7 Average price of vehicle by mileage and fuel type of the car?

# %%
ax = sns.violinplot(x="engtype", y="price",hue='mileage_level', palette="gnuplot", data=cardata)
plt.xlabel("Fuel type", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.ylabel("Price", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
plt.title("Car fuel type Vs. price", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
# Out:
# Text(0.5, 1.0, 'Car fuel type Vs. price')

# %% [markdown]
# In all the fuel types, low mileage car are highly priced. where as the high mileage cars are priced low.

# %% [markdown]
# <a id=section50308></a>
# ## 5.3.8 Average price of vehicles by mileage and eng type?

# %%
# barplot for price based on fuel type and gearbox type
fig, ax = plt.subplots()
colors = ["#00e600", "#ff8c1a","#a180cc"]
sns.barplot(y="price", x="engtype", hue= "mileage_level", data=cardata)
ax.set_title("Average price of vehicles by mileage and eng type", 
             fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.xaxis.set_label_text("Type Of Fuel", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.yaxis.set_label_text("Average Price", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
# Out:
# Text(0, 0.5, 'Average Price')

# %% [markdown]
# __Diesel and Gas__ cars provide highest mileage followed by petrol cars, __Diesel__ cars are highly priced with low mileage.

# %% [markdown]
# <a id=section50309></a>
# ## 5.3.9 Average price of vehicle by drive type over the years of the car (1950 - 2010)?

# %%
ax = sns.lineplot(data=cardata[cardata.year < 2010], y='price', x='year', hue='drive')
plt.title("Average price of vehicle by drive type over the years of the car (1950 - 2010)", 
          fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.xaxis.set_label_text("Year", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.yaxis.set_label_text("Average Price", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
# Out:
# Text(0, 0.5, 'Average Price')

# %% [markdown]
# __Price__ distribution over the years (1953-2016).

# %% [markdown]
# <a id=section50310></a>
# ## 5.3.10 Average price of vehicle by drive type over the years of the car (2010 - 2016)?

# %%
ax = sns.lineplot(data=cardata[cardata.year >= 2010], y='price', x='year', hue='drive')
plt.title("Average price of vehicle by drive type over the years of the car (2010 - 2016)", 
          fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.xaxis.set_label_text("Year", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.yaxis.set_label_text("Average Price", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
# Out:
# Text(0, 0.5, 'Average Price')

# %% [markdown]
# As the years increase, we cannot comment on the price increase, but in general, __there has been an increase in price in recent years.__

# %% [markdown]
# <a id=section50311></a>
# ## 5.3.11 Most preferred body type used over the years of the car?

# %%
ax = sns.countplot(y='body', data=cardata, orient='h', hue='registration')
plt.title("Most preferred body type used in 1953-2016", 
          fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.xaxis.set_label_text("Number of the sold vehicles", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.yaxis.set_label_text("Body Type", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
# Out:
# Text(0, 0.5, 'Body Type')

# %% [markdown]
# The __car brands having "sedan" type of body having maximum registration/sale__ over the years. This shows People prefers __sedan__ type of body mostly and hence this information can be use for achieving max sale and to figure out production of units.

# %% [markdown]
# <a id=section50312></a>
# ## 5.3.12 Most preferred eng type used over the years of the car?

# %%
ax = sns.lineplot(x='mileage',y='price',data=cardata[:100], hue='engtype')
plt.title("Most preferred eng type used over the years of the car", 
          fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.xaxis.set_label_text("Mileage", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.yaxis.set_label_text("Average price", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
# Out:
# Text(0, 0.5, 'Average price')

# %% [markdown]
# Price changing accordingly based on mileage value. So __price is varying based on mileage__ too and this should be considered as a factor for the calculation.

# %% [markdown]
# <a id=section50313></a>
# ## 5.3.13 Most prefered sold or registered vehicle over the years?

# %%
cardata.sort_values(['car','model','body','mileage','year'])

df = cardata.groupby('year')['registration'].value_counts().sort_values(ascending=False)
df = pd.DataFrame(df)
df.rename(columns={'registration': 'RegCounts'}, inplace=True)
df.reset_index(inplace=True)
ax = sns.lineplot(data=df, x='year', y='RegCounts', hue='registration')
#sns.scatterplot(data=df, x='year', y='RegCounts', hue='registration')
plt.title("Most prefered sold or registered vehicle overe the years", 
          fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.xaxis.set_label_text("Production Year", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
ax.yaxis.set_label_text("Registration Count", fontdict={'fontsize': 'medium', 'fontweight': 'heavy'})
# Out:
# Text(0, 0.5, 'Registration Count')

# %% [markdown]
# Shows max sale was done in the Year __2008.__

# %% [markdown]
# <a id=section7></a>
# ## 6. Uncover insights (Answer questions in the data)
#
# - __price__ and __production year__ variables have __strong positive correlation__, i.e. latest production year cars have high  price and older production year cars have lower price.
# - __price and engine volume (engV)__ have __mild positive correlation__.
# - __engine volume (engV) and mileage__ also have some __mild positive correlation__, generally engine volume and mileage do not have positive correlation, but in our data most of the cars have engine volume in between 1.5 CC to 2.5 CC, due to that mileage and engine volume have mild positive correlation.
# - __production year__ and __mileage__ variables have __strong negative correlation__, i.e. latest production year cars have high mileage and older production year cars have low mileage.
# - __price and mileage__ have __negative correlation__, i.e. lower price cars have higher mileage and higher price cars have lower mileage.
# - __production year and engine volume (engV)__ also have some __negative correlation__.
#
# + __Univariate Analysis__
#     1. Which brand of cars sold the most of the car?
#         - The most cars sold by the company __Volkswagen__ followed by __Mercedes-Benz__ and __BMW__.
#     2. Which price range of cars sold the most of the car?
#         - Approx __81%__ of cars sold in the __price range of less than or equal to $20000__.
#     3. Which body type of cars sold the most of the car?
#         - Approx 38% of total cars sold in __Sedan__ body type, 21% in __Crossover__ body type and 13% in __Hatch__ body type.
#         - Sedan are most preferred private cars among public vehicles vans are preferred.
#     4. What is variation of the car sold in terms of mileage of the car?
#         - __Low__ mileage vehicles are prefered.
#     5. Which engine volume cars sold the most of the car?
#         - Below are the __top three categories__ of __Engine Volume (engV)__ cars sold.
#             - __Ist Category__   : > 1.5 & <= 2.5 (In this category approx __56%__ of cars are available)
#             - __IInd Category__  : > 0.5 & <= 1.5 (In this category approx __21%__ of cars are available)
#             - __IIIrd Category__ : > 2.5 & <= 3.5 (In this category approx __14%__ of cars are available)
#         - Out of total cars sold, approx __91%__ cars fall in range of engine volume more than __1.5 CC to  3.5 CC__.
#         - Most of the cars sold have __2.0 CC__ engine volume followed by __1.5 CC__, there are very __few cars sold__ with engine volume __less than equal to 1.0 CC and greater than equal to 4.0 CC__.
#     6. Which engine type cars sold the most of the car?
#         - __Petrol & Diesel__ cars are the most widely sold Engine Type. Gas and Other fuels are not so commonly used.
#     7. What is effect of the car sold in terms of registration of the car?
#         - __Registered__ vehicles are prefered.
#     8. In which production year of cars sold the most of the car?
#         - __Production year 2008 and 2012__ cars are sold the most. Year __2008__ has the highest number of car sales record.
#     9. Which model type of cars sold the most of the car of the car?
#         - __E-Class__ car sold most.
#     10. Which drive type of cars sold the most of the car?
#         - Most sold cars in __front__ drive type, in terms of percentage we can say that, approx 59% of total cars sold in __front__ drive type, 26.09% in __full__ drive type and 15.60% in __rear__ drive type.
#
# + __Bivariate Analysis__
#     1. Which model is the most prefered in top brands of the car?
#         - __Passat & E-Class__ is the most prefered model in __Volkswagen and Mercedes-Benz__ companies respectively.
#     2. Which drive type is the most prefered in top brands of the car?
#         - __Front and rear__ drive is most preferred in __Volkswagen and Mercedes-Benz__ companies respectively.
#     3. Which fuel type is the most prefered in top brands of the car?
#         - __Diesel engines__ are most preferred in __Volkswagen and Mercedes-Benz__ car companies.
#     4. Average price of vehicle by brands?
#         - __Mercedes-Benz__ is the leading brand in higher price segment cars.
#     5. Average price of vehicle by body type?
#         - The most cars sold in price range of __less than 20000__ and majority of these are in __Sedan__  body type.
#         - The majority is __Crossover__ body type in Cars sold at a price __20000 or above__.
#     6. Average price of vehicle by drive type?
#         - The most cars sold in price range of __less than 20000__ and majority of these are in __Front__  drive type.
#         - The majority is __Full__ drive type in Cars sold at a price __20000 or above__.
#     7. Average price of vehicle by mileage?
#         - __Price__ and __mileage__ have __strogly negative correlation__ in sold car dataset , i.e. lower price segment has higher mileage and higher price segment has lower mileage.
#     8. Average price of vehicle by fuel type?
#         - __Diesel__ vehicals are highly priced than __Petrol__ and __Gas__.
#     9. Most preferred registration mode over the years of the car?
#         - Majority of the cars sold with __production year 2008 or later__ were __registered.
#     10. Most prefered drive type with mileage of the car?
#         - __Front drive__ cars are most prefered because of the high mileage they provide followed by __Full drive__ car with very low mileage(<200).
#     11. Most prefered drive type with body type of the car?
#         - __Front__ drive cars are th top most cars in all body type except in __Crossover__ body type.
#         - In __Crossover__ body type __Full__ drive cars are leading.
#     12. Most prefered engine volume with mileage of the car?
#         - Most of the cars sold with __engine volume (engV)__ as 1.5 CC and __mileage__ as approx 200.
#
# + __Multivariate Analysis__
#     1. Pair Plot - What all variables paired with all the other variables of the car?
#         - Price varying based on __Year__ and __Mileage__
#         - As __Year__ increases there is increase in __Petrol__ engine type vehicles's prices which also depending on __mileage__ too.
#         - Majority of the cars with __production year 2008 or later__ sold in __price 50000 or lower__.
#         - All the cars with __production year 2010 or later__ sold in __price more than 50000__.
#         - All the cars with __production year before 2010__ sold in __price 50000 or lower__.
#         - The most cars sold in price range of __less than 20000__ and majority of these are in __Petrol__ engine type.
#         - The majority is __Diesel__ engine type in Cars sold at a price __20000 or above__.
#         - Mileage and price are indirectly related. high priced cars give low mileage.
#     2. Average price of vehicle by body type and drive type of the car?
#         - __All body types__ of cars have __more average price__ for __full drive type__ cars compare to __other drive types__.
#     3. Average price of vehicle by engine type and drive type of the car?
#         - The cars sold in __all engine type__ have __more average price__ for __full drive type__ cars compare to __other drive type__ cars.
#     4. Average price of vehicle by mileage and registration of the car?
#         - __High mileage__ cars are __low priced__ and vise-versa.
#     5. Average price of vehicle by vehicles by fuel type and drive?
#         - __Full drive__ cars of all engine type cars are high priced compared to other fuel types followed by the __Rear drive__ cars in all fuel types.
#         - In Petrol and Diesel Front drive cars are almost equally priced.
#     6. Average price of vehicle by mileage and drive of the car?
#         - In all the car drive types, low mileage car are highly priced. where as the high mileage cars are priced low.
#     7. Average price of vehicle by mileage and fuel type of the car?
#         - In all the fuel types, low mileage car are highly priced. where as the high mileage cars are priced low.
#     8. Average price of vehicles by mileage and eng type?
#         - __Diesel and Gas__ cars provide highest mileage followed by petrol cars, __Diesel__ cars are highly priced with low mileage.
#     9. Average price of vehicle by drive type over the years of the car (1950 - 2016)?
#         - As the years increase, we cannot comment on the price increase, but in general, __there has been an increase in price in recent years.__
#     10. Most preferred body type used over the years of the car?
#         - The __car brands having "sedan" type of body having maximum registration/sale__ over the years. This shows People prefers __sedan__ type of body mostly and hence this information can be use for achieving max sale and to figure out production of units.
#     11. Most preferred eng type used over the years of the car?
#         - Price changing accordingly based on mileage value. So __price is varying based on mileage__ too and this should be consider as a factor for the calculation.
#     12. Most prefered sold or registered vehicle overe the years?
#         - Shows max sale was done in the Year __2008.__

# %% [markdown]
# <a id=section7></a>
# ## 7. Conclusion
#
# - The most cars sold by the company __Volkswagen__ followed by __Mercedes-Benz__ and __BMW__.
# - __Passat & E-Class__ is the most prefered model in __Volkswagen and Mercedes-Benz__ companies respectively.
# - __Front and rear__ drive is most preferred in __Volkswagen and Mercedes-Benz__ companies respectively.
# - __Diesel engines__ are most preferred in __Volkswagen and Mercedes-Benz__ car companies.
# - __Mercedes-Benz__ is the leading brand in higher price segment cars.
#
# - Approx __81%__ of cars sold in the __price range of less than or equal to $20000__ and majority of these are in __Sedan__ body type with __Front__  drive type.
#
# - The majority is __Crossover__ body type in Cars sold at price between __20000 or above__.
# - The majority is __Full__ drive type in Cars sold at a price __20000 or above__.
#
# - __Diesel__ vehicals are highly priced than __Petrol__ and __Gas__.
# - Price varying based on __Year__ and __Mileage__
# - As __Year__ increases there is increase in __Petrol__ engine type vehicles's prices which also depending on __mileage__ too.
# - Majority of the cars with __production year 2008 or later__ sold in __price 50000 or lower__.
# - All the cars with __production year 2010 or later__ sold in __price more than 50000__.
# - All the cars with __production year before 2010__ sold in __price 50000 or lower__.
# - The most cars sold in price range of __less than 20000__ and majority of these are in __Petrol__ engine type.
# - The majority is __Diesel__ engine type in Cars sold at a price __20000 or above__.
# - Mileage and price are indirectly related. high priced cars give low mileage.
#     - __High mileage__ cars are __low priced__ and vise-versa.
#     - __Full drive__ cars of all engine type cars are high priced compared to other fuel types followed by the __Rear drive__ cars in all fuel types.
# - In Petrol and Diesel Front drive cars are almost equally priced.
# - __Diesel and Gas__ cars provide highest mileage followed by petrol cars, __Diesel__ cars are highly priced with low mileage.
#
#
# - Approx 38% of total cars sold in __Sedan__ body type, 21% in __Crossover__ body type and 13% in __Hatch__ body type.
# - __Front__ drive cars are the top most cars in all body type except in __Crossover__ body type.
# - In __Crossover__ body type __Full__ drive cars are leading.
# - The __car brands having "sedan" type of body having maximum registration/sale__ over the years. This shows People prefers __sedan__ type of body mostly and hence this information can be use for achieving max sale and to figure out production of units.
#
# - __Low__ mileage vehicles are prefered.
# - Majority of the cars sold with __production year 2008 or later__ were __registered__.
# - __Front drive__ cars are most prefered because of the high mileage they provide followed by __Full drive__ car with very low mileage(<200).
#
# - Most of the cars sold with __engine volume (engV)__ as 1.5 CC and __mileage__ as approx 200.
#
# - Out of total cars sold, approx __91%__ cars fall in range of engine volume more than __1.5 CC to  3.5 CC__.
# - Most of the cars sold have __2.0 CC__ engine volume followed by __1.5 CC__, there are very __few cars sold__ with engine volume __less than equal to 1.0 CC and greater than equal to 4.0 CC__.
#
#
# - __Petrol & Diesel__ cars are the most widely sold Engine Type. Gas and Other fuels are not so commonly used.
#
#
# - __Registered__ vehicles are prefered.
#
#
# - __Production year 2008 and 2012__ cars are sold the most. Year __2008__ has the highest number of car sales record.

# %% [markdown]
# <a id=section8></a>
# ## 8. Actionable Insights
#
# - Low milege cars with high priced can be recomed for highly profiled customer.
# - __Crossover__ body type is prefered in __Full drive type__ thus the same experiment can be applied with __Sadan__.
